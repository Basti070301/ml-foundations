# %% [markdown]
# ## Programmieraufgabe (Python)
#
# Entwickle in Python ein Programm, das:
#
# 1. die Daten aus dem heruntergeladenen Datensatz liest und lädt
# 2. eine Output-Variable **„Guter Wein“** definiert (**Weinqualität mindestens 7**)
# 3. den Datensatz in einen **Trainingsdatensatz**, einen **Validierungsdatensatz** und einen **Testdatensatz** teilt
# 4. jedes Eingangsmerkmal der Daten gemäß der **Z-Score-Normalisierung** skaliert
# 5. mindestens **10 k-Nearest-Neighbour Klassifikatoren** mit verschiedenen Werten für **k** trainiert
# 6. jeden Klassifikator anhand des **Validierungsdatensatzes** bewertet und den **besten Klassifikator** auswählt
# 7. die **Genauigkeit (Accuracy)** für bisher ungesehene Daten unter Verwendung des **Testdatensatzes** berechnet

# %%
import pandas as pd

# %% [markdown]
# ### Daten einlesen

# %%
wine_data = pd.read_csv('..\\Data\\raw\\wine_quality_data.csv')
wine_data.head()
